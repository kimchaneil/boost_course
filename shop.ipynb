# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
os.name
# Out:
# 'nt'

# %%
sns.set(font='Malgun Gothic')

# %%
df_raw=pd.read_csv('./data/shop/shop.csv',encoding='cp949')
df_raw.shape
# Out:
# (450, 27)

# %%
df
# Out:
#       국가(대륙)별          상품군별   판매유형별        기간   백만원    연도  분기
# 48         미국    컴퓨터 및 주변기기       계  2014.1/4  2216  2014   1
# 49         미국    컴퓨터 및 주변기기     면세점  2014.1/4     -  2014   1
# 50         미국    컴퓨터 및 주변기기  면세점 이외  2014.1/4     -  2014   1
# 51         미국    가전·전자·통신기기       계  2014.1/4  2875  2014   1
# 52         미국    가전·전자·통신기기     면세점  2014.1/4     -  2014   1
# ...       ...           ...     ...       ...   ...   ...  ..
# 10795      기타  생활용품 및 자동차용품     면세점  2019.4/4     0  2019   4
# 10796      기타  생활용품 및 자동차용품  면세점 이외  2019.4/4   531  2019   4
# 10797      기타           기 타       계  2019.4/4  1094  2019   4
# 10798      기타           기 타     면세점  2019.4/4     1  2019   4
# 10799      기타           기 타  면세점 이외  2019.4/4  1093  2019   4
#
# [9072 rows x 7 columns]

# %%
df_raw['국가(대륙)별'].value_counts()
# Out:
# 합계            45
# 미국            45
# 중국            45
# 일본            45
# 아세안(ASEAN)    45
# 유럽연합(EU)      45
# 중동            45
# 중남미           45
# 대양주           45
# 기타            45
# Name: 국가(대륙)별, dtype: int64

# %%
df_raw[df_raw['국가(대륙)별']=='미국']
# Out:
#    국가(대륙)별          상품군별   판매유형별 2014.1/4 2014.2/4 2014.3/4 2014.4/4 2015.1/4  \
# 45      미국            합계       계    25773    22573    21288    26729    39945
# 46      미국            합계     면세점        -        -        -        -        -
# 47      미국            합계  면세점 이외        -        -        -        -        -
# 48      미국    컴퓨터 및 주변기기       계     2216     1666     1776     1675     1469
# 49      미국    컴퓨터 및 주변기기     면세점        -        -        -        -        -
# 50      미국    컴퓨터 및 주변기기  면세점 이외        -        -        -        -        -
# 51      미국    가전·전자·통신기기       계     2875     2758     2894     3527     4397
# 52      미국    가전·전자·통신기기     면세점        -        -        -        -        -
# 53      미국    가전·전자·통신기기  면세점 이외        -        -        -        -        -
# 54      미국         소프트웨어       계       47       57       49      128      182
# 55      미국         소프트웨어     면세점        -        -        -        -        -
# 56      미국         소프트웨어  면세점 이외        -        -        -        -        -
# 57      미국           서 적       계      962      720      934     1006     1074
# 58      미국           서 적     면세점        -        -        -        -        -
# 59      미국           서 적  면세점 이외        -        -        -        -        -
# 60      미국         사무·문구       계       25       10       14       18      568
# 61      미국         사무·문구     면세점        -        -        -        -        -
# 62      미국         사무·문구  면세점 이외        -        -        -        -        -
# 63      미국     음반·비디오·악기       계      787      720      722      821      849
# 64      미국     음반·비디오·악기     면세점        -        -        -        -        -
# 65      미국     음반·비디오·악기  면세점 이외        -        -        -        -        -
# 66      미국  의류 및 패션 관련상품       계     9810     7801     6404     9208     8602
# 67      미국  의류 및 패션 관련상품     면세점        -        -        -        -        -
# 68      미국  의류 및 패션 관련상품  면세점 이외        -        -        -        -        -
# 69      미국      스포츠·레저용품       계      573      539      475      491      541
# 70      미국      스포츠·레저용품     면세점        -        -        -        -        -
# 71      미국      스포츠·레저용품  면세점 이외        -        -        -        -        -
# 72      미국           화장품       계     3740     3713     3399     4595    11223
# 73      미국           화장품     면세점        -        -        -        -        -
# 74      미국           화장품  면세점 이외        -        -        -        -        -
# 75      미국       아동·유아용품       계      583      546      499      610     1099
# 76      미국       아동·유아용품     면세점        -        -        -        -        -
# 77      미국       아동·유아용품  면세점 이외        -        -        -        -        -
# 78      미국         음·식료품       계      381      415      405      673      577
# 79      미국         음·식료품     면세점        -        -        -        -        -
# 80      미국         음·식료품  면세점 이외        -        -        -        -        -
# 81      미국         농축수산물       계       94       98      111      160      189
# 82      미국         농축수산물     면세점        -        -        -        -        -
# 83      미국         농축수산물  면세점 이외        -        -        -        -        -
# 84      미국  생활용품 및 자동차용품       계     1931     1915     1815     1871     6605
# 85      미국  생활용품 및 자동차용품     면세점        -        -        -        -        -
# 86      미국  생활용품 및 자동차용품  면세점 이외        -        -        -        -        -
# 87      미국           기 타       계     1749     1615     1791     1946     2570
# 88      미국           기 타     면세점        -        -        -        -        -
# 89      미국           기 타  면세점 이외        -        -        -        -        -
#
#    2015.2/4 2015.3/4  ... 2017.3/4 2017.4/4 2018.1/4 2018.2/4 2018.3/4  \
# 45    26654    28647  ...    42331    53209    42679    40207    37631
# 46        -        -  ...     9469    12177     5184     3603     2317
# 47        -        -  ...    32862    41032    37495    36604    35314
# 48     1393     2166  ...      802      854     2033     1553     1784
# 49        -        -  ...        0        0        0        0        0
# 50        -        -  ...      802      854     2033     1553     1784
# 51     3589     2982  ...     2631     2394     1737     1716     1723
# 52        -        -  ...       29       32       65       38       72
# 53        -        -  ...     2602     2362     1672     1678     1651
# 54      113      163  ...      123      125      175      251      172
# 55        -        -  ...        0        0        0        0        0
# 56        -        -  ...      123      125      175      251      172
# 57      837      993  ...     1876     1856     2089     1790     2033
# 58        -        -  ...        0        0        0        0        0
# 59        -        -  ...     1876     1856     2089     1790     2033
# 60       17       32  ...       41       79       58       55       85
# 61        -        -  ...        0        0        0        0        0
# 62        -        -  ...       41       79       58       55       85
# 63      781      827  ...     2361     2647     2362     3014     3932
# 64        -        -  ...        0        0        0        0        0
# 65        -        -  ...     2361     2647     2362     3014     3932
# 66     6927     8055  ...    11205    14483    11815    12169    10233
# 67        -        -  ...      148      129      116      154      134
# 68        -        -  ...    11057    14354    11699    12015    10099
# 69      527      481  ...      877     1121     1181     1439     1200
# 70        -        -  ...        0        0        0        0        1
# 71        -        -  ...      877     1121     1181     1439     1199
# 72     6176     7061  ...    16016    22310    13909    11219     9717
# 73        -        -  ...     9202    11913     4927     3311     2028
# 74        -        -  ...     6814    10397     8982     7908     7689
# 75      603      619  ...      619      722      766      793      730
# 76        -        -  ...        1        0        1        0        2
# 77        -        -  ...      618      722      765      793      728
# 78      628      631  ...      415      265      277      311      239
# 79        -        -  ...       89      103       75      100       80
# 80        -        -  ...      326      162      202      211      159
# 81      192      193  ...        0        2        1        0        0
# 82        -        -  ...        0        0        0        0        0
# 83        -        -  ...        0        2        1        0        0
# 84     2189     2207  ...     2396     2276     2483     2357     2150
# 85        -        -  ...        0        0        0        0        0
# 86        -        -  ...     2396     2276     2483     2357     2150
# 87     2682     2237  ...     2969     4075     3793     3540     3633
# 88        -        -  ...        0        0        0        0        0
# 89        -        -  ...     2969     4075     3793     3540     3633
#
#     2018.4/4  2019.1/4  2019.2/4  2019.3/4  2019.4/4
# 45     48978     40985     44973     55512     54054
# 46      2079      2657      2951      1818      1481
# 47     46899     38328     42022     53694     52573
# 48      1774      1298      1408      1653      1383
# 49         1         0         0         0         0
# 50      1773      1298      1408      1653      1383
# 51      1886      1845      1837      3166      1787
# 52        52        66       116       107        49
# 53      1834      1779      1721      3059      1738
# 54       269        88       156       118       338
# 55         0         0         0         0         0
# 56       269        88       156       118       338
# 57      1977      2259      1563      2596      1720
# 58         0         0         0         0         0
# 59      1977      2259      1563      2596      1720
# 60        83       198        72        83       101
# 61         0         0         0         0         0
# 62        83       198        72        83       101
# 63      4550      3857      5191      5762      4786
# 64         0         0         0         0         0
# 65      4550      3857      5191      5762      4786
# 66     13658     12324     13683     13368     16161
# 67       118       110       115        95        91
# 68     13540     12214     13568     13273     16070
# 69      1072      1152      1602      3150       864
# 70         3         4         0         0         0
# 71      1069      1148      1602      3150       864
# 72     15738     10817     11310     13999     13494
# 73      1780      2366      2647      1550      1271
# 74     13958      8451      8663     12449     12223
# 75      1056       815      1153      1702      1928
# 76         0         0         0         0         0
# 77      1056       815      1153      1702      1928
# 78       278       336       313       602       424
# 79       125       111        73        64        70
# 80       153       225       240       538       354
# 81        33         2         2         7         2
# 82         0         0         0         0         0
# 83        33         2         2         7         2
# 84      2159      2174      2410      3409      3713
# 85         0         0         0         2         0
# 86      2159      2174      2410      3407      3713
# 87      4445      3820      4273      5897      7353
# 88         0         0         0         0         0
# 89      4445      3820      4273      5897      7353
#
# [45 rows x 27 columns]

# %%
df_raw.melt(id_vars=['국가(대륙)별','상품군별','판매유형별'])
# Out:
#       국가(대륙)별          상품군별   판매유형별  variable   value
# 0          합계            합계       계  2014.1/4  148272
# 1          합계            합계     면세점  2014.1/4       -
# 2          합계            합계  면세점 이외  2014.1/4       -
# 3          합계    컴퓨터 및 주변기기       계  2014.1/4    4915
# 4          합계    컴퓨터 및 주변기기     면세점  2014.1/4       -
# ...       ...           ...     ...       ...     ...
# 10795      기타  생활용품 및 자동차용품     면세점  2019.4/4       0
# 10796      기타  생활용품 및 자동차용품  면세점 이외  2019.4/4     531
# 10797      기타           기 타       계  2019.4/4    1094
# 10798      기타           기 타     면세점  2019.4/4       1
# 10799      기타           기 타  면세점 이외  2019.4/4    1093
#
# [10800 rows x 5 columns]

# %%
df = df_raw.melt(id_vars=['국가(대륙)별','상품군별','판매유형별'],var_name='기간',value_name='백만원')
df.shape
# Out:
# (10800, 5)

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10800 entries, 0 to 10799
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   국가(대륙)별  10800 non-null  object
#  1   상품군별     10800 non-null  object
#  2   판매유형별    10800 non-null  object
#  3   기간       10800 non-null  object
#  4   백만원      10800 non-null  object
# dtypes: object(5)
# memory usage: 422.0+ KB

# %%
df['기간']
# Out:
# 0        2014.1/4
# 1        2014.1/4
# 2        2014.1/4
# 3        2014.1/4
# 4        2014.1/4
#            ...
# 10795    2019.4/4
# 10796    2019.4/4
# 10797    2019.4/4
# 10798    2019.4/4
# 10799    2019.4/4
# Name: 기간, Length: 10800, dtype: object

# %%
'2019 4/4 p)'.split()[0]
#str형
# Out:
# '2019'

# %%
df['기간'].map(lambda x: int(x.split('.')[0]))
# Out:
# 0        2014
# 1        2014
# 2        2014
# 3        2014
# 4        2014
#          ...
# 10795    2019
# 10796    2019
# 10797    2019
# 10798    2019
# 10799    2019
# Name: 기간, Length: 10800, dtype: int64

# %%
df["연도"] = df["기간"].map(lambda x : int(x.split('.')[0]))
df.head()
# Out:
#   국가(대륙)별        상품군별   판매유형별        기간     백만원    연도
# 0      합계          합계       계  2014.1/4  148272  2014
# 1      합계          합계     면세점  2014.1/4       -  2014
# 2      합계          합계  면세점 이외  2014.1/4       -  2014
# 3      합계  컴퓨터 및 주변기기       계  2014.1/4    4915  2014
# 4      합계  컴퓨터 및 주변기기     면세점  2014.1/4       -  2014

# %%
df['분기']=df['기간'].map(lambda x: int(x.split('.')[1].split('/')[0]))
df.head()
# Out:
#   국가(대륙)별        상품군별   판매유형별        기간     백만원    연도  분기
# 0      합계          합계       계  2014.1/4  148272  2014   1
# 1      합계          합계     면세점  2014.1/4       -  2014   1
# 2      합계          합계  면세점 이외  2014.1/4       -  2014   1
# 3      합계  컴퓨터 및 주변기기       계  2014.1/4    4915  2014   1
# 4      합계  컴퓨터 및 주변기기     면세점  2014.1/4       -  2014   1

# %%
df['백만원'].replace('-',pd.np.nan)
# Out:
# C:\Users\chane\AppData\Local\Temp\ipykernel_12280\1587238849.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   df['백만원'].replace('-',pd.np.nan)
# 0        148272
# 1           NaN
# 2           NaN
# 3          4915
# 4           NaN
#           ...
# 10795         0
# 10796       531
# 10797      1094
# 10798         1
# 10799      1093
# Name: 백만원, Length: 10800, dtype: object

# %%
df['백만원'].replace('-',pd.np.nan).astype(float)
df['백만원']
# Out:
# C:\Users\chane\AppData\Local\Temp\ipykernel_12280\1377345439.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   df['백만원'].replace('-',pd.np.nan).astype(float)
# 0        148272
# 1             -
# 2             -
# 3          4915
# 4             -
#           ...
# 10795         0
# 10796       531
# 10797      1094
# 10798         1
# 10799      1093
# Name: 백만원, Length: 10800, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9072 entries, 48 to 10799
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   국가(대륙)별  9072 non-null   object
#  1   상품군별     9072 non-null   object
#  2   판매유형별    9072 non-null   object
#  3   기간       9072 non-null   object
#  4   백만원      9072 non-null   object
#  5   연도       9072 non-null   int64
#  6   분기       9072 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 567.0+ KB

# %%
df = df[(df['국가(대륙)별']!= '합계') & (df['상품군별'] != '합계')].copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9072 entries, 48 to 10799
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   국가(대륙)별  9072 non-null   object
#  1   상품군별     9072 non-null   object
#  2   판매유형별    9072 non-null   object
#  3   기간       9072 non-null   object
#  4   백만원      9072 non-null   object
#  5   연도       9072 non-null   int64
#  6   분기       9072 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 567.0+ KB

# %%
df.isnull().sum()
# Out:
# 국가(대륙)별    0
# 상품군별       0
# 판매유형별      0
# 기간         0
# 백만원        0
# 연도         0
# 분기         0
# dtype: int64

# %%
df_total=df[df['판매유형별']=='계'].copy()
df_total['백만원'] = df_total['백만원'].astype(float)
df_total
# Out:
#       국가(대륙)별          상품군별 판매유형별        기간     백만원    연도  분기
# 48         미국    컴퓨터 및 주변기기     계  2014.1/4  2216.0  2014   1
# 51         미국    가전·전자·통신기기     계  2014.1/4  2875.0  2014   1
# 54         미국         소프트웨어     계  2014.1/4    47.0  2014   1
# 57         미국           서 적     계  2014.1/4   962.0  2014   1
# 60         미국         사무·문구     계  2014.1/4    25.0  2014   1
# ...       ...           ...   ...       ...     ...   ...  ..
# 10785      기타       아동·유아용품     계  2019.4/4   193.0  2019   4
# 10788      기타         음·식료품     계  2019.4/4   319.0  2019   4
# 10791      기타         농축수산물     계  2019.4/4     2.0  2019   4
# 10794      기타  생활용품 및 자동차용품     계  2019.4/4   531.0  2019   4
# 10797      기타           기 타     계  2019.4/4  1094.0  2019   4
#
# [3024 rows x 7 columns]

# %%
sns.lineplot(data=df_total, x="연도", y="백만원")
# Out:
# <Axes: xlabel='연도', ylabel='백만원'>

# %%
sns.lineplot(data=df_total,x='연도',y='백만원',hue='상품군별')
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0)

# %%
sns.relplot(data=df_total, x="연도", y="백만원", hue="상품군별", kind="line")

# %%
sns.relplot(data=df_total,x='연도',y='백만원',hue='상품군별',kind='line',col='상품군별',col_wrap=4)

# %%
df_sub = df_total[~df_total['상품군별'].isin(['화장품'])].copy()
df_sub
# Out:
#       국가(대륙)별          상품군별 판매유형별        기간     백만원    연도  분기
# 48         미국    컴퓨터 및 주변기기     계  2014.1/4  2216.0  2014   1
# 51         미국    가전·전자·통신기기     계  2014.1/4  2875.0  2014   1
# 54         미국         소프트웨어     계  2014.1/4    47.0  2014   1
# 57         미국           서 적     계  2014.1/4   962.0  2014   1
# 60         미국         사무·문구     계  2014.1/4    25.0  2014   1
# ...       ...           ...   ...       ...     ...   ...  ..
# 10785      기타       아동·유아용품     계  2019.4/4   193.0  2019   4
# 10788      기타         음·식료품     계  2019.4/4   319.0  2019   4
# 10791      기타         농축수산물     계  2019.4/4     2.0  2019   4
# 10794      기타  생활용품 및 자동차용품     계  2019.4/4   531.0  2019   4
# 10797      기타           기 타     계  2019.4/4  1094.0  2019   4
#
# [2808 rows x 7 columns]

# %%
sns.relplot(data=df_sub, x="연도", y="백만원", hue="상품군별", col="상품군별", col_wrap=4, kind="line")

# %%
df_sub = df_total[~df_total["상품군별"].isin(["화장품", "의류 및 패션 관련상품"])].copy()
sns.relplot(data=df_sub, x="연도", y="백만원", hue="상품군별", col="상품군별", col_wrap=4, kind="line")

# %%
df_total['상품군별'] == '화장품'
# Out:
# 48       False
# 51       False
# 54       False
# 57       False
# 60       False
#          ...
# 10785    False
# 10788    False
# 10791    False
# 10794    False
# 10797    False
# Name: 상품군별, Length: 3024, dtype: bool

# %%
df_cos = df_total[df_total['상품군별']=='화장품'].copy()
df_cos
# Out:
#           국가(대륙)별 상품군별 판매유형별        기간      백만원    연도  분기
# 72             미국  화장품     계  2014.1/4   3740.0  2014   1
# 117            중국  화장품     계  2014.1/4  32235.0  2014   1
# 162            일본  화장품     계  2014.1/4   1034.0  2014   1
# 207    아세안(ASEAN)  화장품     계  2014.1/4    398.0  2014   1
# 252      유럽연합(EU)  화장품     계  2014.1/4    937.0  2014   1
# ...           ...  ...   ...       ...      ...   ...  ..
# 10602    유럽연합(EU)  화장품     계  2019.4/4   3912.0  2019   4
# 10647          중동  화장품     계  2019.4/4   1134.0  2019   4
# 10692         중남미  화장품     계  2019.4/4    638.0  2019   4
# 10737         대양주  화장품     계  2019.4/4   1094.0  2019   4
# 10782          기타  화장품     계  2019.4/4  17315.0  2019   4
#
# [216 rows x 7 columns]

# %%
df_cos['상품군별'].unique()
# Out:
# array(['화장품'], dtype=object)

# %%
sns.lineplot(data=df_cos,x='연도',y='백만원')
# Out:
# <Axes: xlabel='연도', ylabel='백만원'>

# %%
plt.figure(figsize=(15,4))
sns.lineplot(data=df_cos,x='연도',y='백만원',hue='분기')
# Out:
# <Axes: xlabel='연도', ylabel='백만원'>

# %%
plt.figure(figsize=(15,4))
plt.xticks(rotation=30)
sns.lineplot(data=df_cos,x='기간',y='백만원')
# Out:
# <Axes: xlabel='기간', ylabel='백만원'>

# %%
df_cos.head()
# Out:
#         국가(대륙)별 상품군별 판매유형별        기간      백만원    연도  분기
# 72           미국  화장품     계  2014.1/4   3740.0  2014   1
# 117          중국  화장품     계  2014.1/4  32235.0  2014   1
# 162          일본  화장품     계  2014.1/4   1034.0  2014   1
# 207  아세안(ASEAN)  화장품     계  2014.1/4    398.0  2014   1
# 252    유럽연합(EU)  화장품     계  2014.1/4    937.0  2014   1

# %%
plt.figure(figsize=(15,4))
plt.xticks(rotation=30)
sns.lineplot(data=df_cos,x='기간',y='백만원',hue='국가(대륙)별')
# Out:
# <Axes: xlabel='기간', ylabel='백만원'>

# %%
plt.figure(figsize=(15,4))
plt.xticks(rotation=30)
sns.lineplot(data=df_cos[df_cos["국가(대륙)별"] != "중국"], x="기간",y="백만원" ,hue="국가(대륙)별")
# Out:
# <Axes: xlabel='기간', ylabel='백만원'>

# %%
plt.figure(figsize=(15,4))
plt.xticks(rotation=30)
df_sub=df[df['판매유형별']!= '계'].copy()
df_sub.replace('-','NaN')
df_sub
#sns.lineplot(data=df_sub ,x='기간',y='백만원',hue='판매유형별')
# Out:
#       국가(대륙)별          상품군별   판매유형별        기간   백만원    연도  분기
# 49         미국    컴퓨터 및 주변기기     면세점  2014.1/4     -  2014   1
# 50         미국    컴퓨터 및 주변기기  면세점 이외  2014.1/4     -  2014   1
# 52         미국    가전·전자·통신기기     면세점  2014.1/4     -  2014   1
# 53         미국    가전·전자·통신기기  면세점 이외  2014.1/4     -  2014   1
# 55         미국         소프트웨어     면세점  2014.1/4     -  2014   1
# ...       ...           ...     ...       ...   ...   ...  ..
# 10793      기타         농축수산물  면세점 이외  2019.4/4     2  2019   4
# 10795      기타  생활용품 및 자동차용품     면세점  2019.4/4     0  2019   4
# 10796      기타  생활용품 및 자동차용품  면세점 이외  2019.4/4   531  2019   4
# 10798      기타           기 타     면세점  2019.4/4     1  2019   4
# 10799      기타           기 타  면세점 이외  2019.4/4  1093  2019   4
#
# [6048 rows x 7 columns]

# %%
df_fashion = df[df["상품군별"] == "의류 및 패션 관련상품"].copy()
df_fashion.head()
# Out:
#     국가(대륙)별          상품군별   판매유형별        기간    백만원    연도  분기
# 66       미국  의류 및 패션 관련상품       계  2014.1/4   9810  2014   1
# 67       미국  의류 및 패션 관련상품     면세점  2014.1/4      -  2014   1
# 68       미국  의류 및 패션 관련상품  면세점 이외  2014.1/4      -  2014   1
# 111      중국  의류 및 패션 관련상품       계  2014.1/4  12206  2014   1
# 112      중국  의류 및 패션 관련상품     면세점  2014.1/4      -  2014   1

# %%
df_fashion = df[(df["상품군별"] == "의류 및 패션 관련상품") & (df["판매유형별"] == "계")].copy()
df_fashion.head()
# Out:
#         국가(대륙)별          상품군별 판매유형별        기간    백만원    연도  분기
# 66           미국  의류 및 패션 관련상품     계  2014.1/4   9810  2014   1
# 111          중국  의류 및 패션 관련상품     계  2014.1/4  12206  2014   1
# 156          일본  의류 및 패션 관련상품     계  2014.1/4  13534  2014   1
# 201  아세안(ASEAN)  의류 및 패션 관련상품     계  2014.1/4   3473  2014   1
# 246    유럽연합(EU)  의류 및 패션 관련상품     계  2014.1/4   1364  2014   1

# %%
plt.figure(figsize=(15, 4))
plt.xticks(rotation=30)
df_fashion['백만원'] = df_fashion['백만원'].astype(float)
sns.lineplot(data=df_fashion, x="기간", y="백만원", hue="국가(대륙)별")
# Out:
# <Axes: xlabel='기간', ylabel='백만원'>

# %%
df_fashion2 = df[(df["상품군별"] == "의류 및 패션 관련상품") & (df["판매유형별"] != "계")].copy()
df_fashion2['백만원'] = df_fashion2['백만원'].replace('-', pd.NA)
df_fashion2 = df_fashion2[df_fashion2['백만원'].notna()]
df_fashion2['백만원'] = df_fashion2['백만원'].astype(float)
plt.figure(figsize=(15, 4))
plt.xticks(rotation=30)
sns.lineplot(data=df_fashion2, x="기간", y="백만원", hue="판매유형별", errorbar=None)
# Out:
# <Axes: xlabel='기간', ylabel='백만원'>

# %%
df_fashion
# Out:
#           국가(대륙)별          상품군별 판매유형별        기간      백만원    연도  분기
# 66             미국  의류 및 패션 관련상품     계  2014.1/4   9810.0  2014   1
# 111            중국  의류 및 패션 관련상품     계  2014.1/4  12206.0  2014   1
# 156            일본  의류 및 패션 관련상품     계  2014.1/4  13534.0  2014   1
# 201    아세안(ASEAN)  의류 및 패션 관련상품     계  2014.1/4   3473.0  2014   1
# 246      유럽연합(EU)  의류 및 패션 관련상품     계  2014.1/4   1364.0  2014   1
# ...           ...           ...   ...       ...      ...   ...  ..
# 10596    유럽연합(EU)  의류 및 패션 관련상품     계  2019.4/4    862.0  2019   4
# 10641          중동  의류 및 패션 관련상품     계  2019.4/4    251.0  2019   4
# 10686         중남미  의류 및 패션 관련상품     계  2019.4/4    124.0  2019   4
# 10731         대양주  의류 및 패션 관련상품     계  2019.4/4    651.0  2019   4
# 10776          기타  의류 및 패션 관련상품     계  2019.4/4   1774.0  2019   4
#
# [216 rows x 7 columns]

# %%
df_fashion.pivot_table(index="국가(대륙)별", columns="연도", values="백만원")
# Out:
# 연도              2014      2015      2016      2017      2018      2019
# 국가(대륙)별
# 기타           2420.75   1812.00   1479.50   3298.00   5975.25   1618.75
# 대양주           848.00    587.25    850.25    679.00    681.25    622.25
# 미국           8305.75   9516.50  12112.75  12909.50  11968.75  13884.00
# 아세안(ASEAN)   3734.00   4909.75   6119.50   6074.25   5767.00   7811.75
# 유럽연합(EU)     1121.25    843.50   1224.75   1022.75   1028.50    923.50
# 일본          12240.00  14398.50  19976.25  22632.75  34200.00  33659.25
# 중국          14382.75  35584.75  47733.00  57082.50  72212.00  82566.75
# 중남미           243.75    154.00    162.25    193.00    144.00    136.00
# 중동            293.00    254.50    242.00    202.00    219.75    237.75

# %%
df_fashion.pivot_table(index="국가(대륙)별", columns="연도", values="백만원",aggfunc='sum')
# Out:
# 연도             2014      2015      2016      2017      2018      2019
# 국가(대륙)별
# 기타           9683.0    7248.0    5918.0   13192.0   23901.0    6475.0
# 대양주          3392.0    2349.0    3401.0    2716.0    2725.0    2489.0
# 미국          33223.0   38066.0   48451.0   51638.0   47875.0   55536.0
# 아세안(ASEAN)  14936.0   19639.0   24478.0   24297.0   23068.0   31247.0
# 유럽연합(EU)     4485.0    3374.0    4899.0    4091.0    4114.0    3694.0
# 일본          48960.0   57594.0   79905.0   90531.0  136800.0  134637.0
# 중국          57531.0  142339.0  190932.0  228330.0  288848.0  330267.0
# 중남미           975.0     616.0     649.0     772.0     576.0     544.0
# 중동           1172.0    1018.0     968.0     808.0     879.0     951.0

# %%
df_fashion["판매유형별"].value_counts()
# Out:
# 계    216
# Name: 판매유형별, dtype: int64

# %%
result = df_fashion.pivot_table(index="국가(대륙)별", columns="연도", values="백만원", aggfunc="sum")
result
# Out:
# 연도             2014      2015      2016      2017      2018      2019
# 국가(대륙)별
# 기타           9683.0    7248.0    5918.0   13192.0   23901.0    6475.0
# 대양주          3392.0    2349.0    3401.0    2716.0    2725.0    2489.0
# 미국          33223.0   38066.0   48451.0   51638.0   47875.0   55536.0
# 아세안(ASEAN)  14936.0   19639.0   24478.0   24297.0   23068.0   31247.0
# 유럽연합(EU)     4485.0    3374.0    4899.0    4091.0    4114.0    3694.0
# 일본          48960.0   57594.0   79905.0   90531.0  136800.0  134637.0
# 중국          57531.0  142339.0  190932.0  228330.0  288848.0  330267.0
# 중남미           975.0     616.0     649.0     772.0     576.0     544.0
# 중동           1172.0    1018.0     968.0     808.0     879.0     951.0

# %%
sns.heatmap(result)
# Out:
# <Axes: xlabel='연도', ylabel='국가(대륙)별'>

# %%
sns.heatmap(result, cmap = "Blues_r",annot=True)
# Out:
# <Axes: xlabel='연도', ylabel='국가(대륙)별'>

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(result, cmap="Blues_r", annot=True, fmt=".0f")
# Out:
# <Axes: xlabel='연도', ylabel='국가(대륙)별'>

# %%
df_total
# Out:
#       국가(대륙)별          상품군별 판매유형별        기간     백만원    연도  분기
# 48         미국    컴퓨터 및 주변기기     계  2014.1/4  2216.0  2014   1
# 51         미국    가전·전자·통신기기     계  2014.1/4  2875.0  2014   1
# 54         미국         소프트웨어     계  2014.1/4    47.0  2014   1
# 57         미국           서 적     계  2014.1/4   962.0  2014   1
# 60         미국         사무·문구     계  2014.1/4    25.0  2014   1
# ...       ...           ...   ...       ...     ...   ...  ..
# 10785      기타       아동·유아용품     계  2019.4/4   193.0  2019   4
# 10788      기타         음·식료품     계  2019.4/4   319.0  2019   4
# 10791      기타         농축수산물     계  2019.4/4     2.0  2019   4
# 10794      기타  생활용품 및 자동차용품     계  2019.4/4   531.0  2019   4
# 10797      기타           기 타     계  2019.4/4  1094.0  2019   4
#
# [3024 rows x 7 columns]

# %%
sns.barplot(data=df_total, x="연도", y="백만원")
# Out:
# <Axes: xlabel='연도', ylabel='백만원'>

# %%
plt.figure(figsize=(15,4))
sns.lineplot(data=df_total, x='연도',y='백만원',hue='국가(대륙)별')
# Out:
# <Axes: xlabel='연도', ylabel='백만원'>

# %%
plt.figure(figsize=(15, 4))
sns.lineplot(data=df_total, x="연도", y="백만원", hue="상품군별")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0,)
